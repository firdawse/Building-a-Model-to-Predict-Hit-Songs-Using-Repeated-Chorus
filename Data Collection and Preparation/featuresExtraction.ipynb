# %%
import librosa
import numpy as np
import scipy
from scipy.stats import skew, kurtosis
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.ensemble import RandomForestRegressor

# %%
pip install eli5
# Out:
# Collecting eli5Note: you may need to restart the kernel to use updated packages.
#
#   Downloading eli5-0.13.0.tar.gz (216 kB)
#      -------------------------------------- 216.2/216.2 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: attrs>17.1.0 in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (22.1.0)
# Requirement already satisfied: jinja2>=3.0.0 in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (3.1.2)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (1.23.5)
# Requirement already satisfied: scipy in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (1.10.0)
# Requirement already satisfied: six in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (1.16.0)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (1.2.1)
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.0/47.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\slayer\anaconda3\lib\site-packages (from eli5) (0.8.10)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\slayer\anaconda3\lib\site-packages (from jinja2>=3.0.0->eli5) (2.1.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\slayer\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\slayer\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (2.2.0)
# Building wheels for collected packages: eli5
#   Building wheel for eli5 (setup.py): started
#   Building wheel for eli5 (setup.py): finished with status 'done'
#   Created wheel for eli5: filename=eli5-0.13.0-py2.py3-none-any.whl size=107768 sha256=1d74a4b2edff97267aad64250c81d405cf9978902f13778b5b63d63a152d3a60
#   Stored in directory: c:\users\slayer\appdata\local\pip\cache\wheels\79\6c\4b\13ea3238d017bc19711b4312359e2c95be91a1a9d60d949572
# Successfully built eli5
# Installing collected packages: graphviz, eli5
# Successfully installed eli5-0.13.0 graphviz-0.20.1

# %%
import pandas as pd
df=pd.read_csv('data.csv')

# %%
df=df.drop(['chroma_stft','chroma_cqt','chroma_cens','mfcc','spectral_centroid','rms','spectral_bandwidth','spectral_rolloff','tonnetz','zero_crossing_rate'],axis=1)

# %%
df=df.drop(['spectral_contrast'],axis=1)

# %%
df
# Out:
#                           title                         artist  Popularity
# 0                    Heat Waves                  Glass Animals           1
# 1                     As It Was                   Harry Styles           1
# 2                          Stay  The Kid LAROI & Justin Bieber           1
# 3                    Easy On Me                          Adele           1
# 4                       Shivers                     Ed Sheeran           1
# ..                          ...                            ...         ...
# 886   Havana (feat. Young Thug)                 Camila Cabello           0
# 887     My Oh My (feat. DaBaby)                 Camila Cabello           0
# 888                Don't Go Yet                 Camila Cabello           0
# 889  Bam Bam (feat. Ed Sheeran)                 Camila Cabello           0
# 890                    Paradise                          Bazzi           0
#
# [891 rows x 3 columns]

# %%
audio_file = f"C:/Users/slayer/Desktop/Newfolder2/Easy On Me Adele.wav"
y, sr = librosa.load(audio_file)
librosa.feature.chroma_stft(y=y, sr=sr)
# Out:
# array([[0.69365716, 0.44952786, 0.3642355 , ..., 1.        , 1.        ,
#         1.        ],
#        [0.42246294, 0.17675875, 0.13507453, ..., 0.20903067, 0.225832  ,
#         0.23392294],
#        [0.30194542, 0.06923891, 0.04702541, ..., 0.01701631, 0.01626185,
#         0.0190421 ],
#        ...,
#        [0.8553067 , 0.6237905 , 0.53972346, ..., 0.05733059, 0.02449311,
#         0.01649385],
#        [1.        , 1.        , 1.        , ..., 0.04947283, 0.03300176,
#         0.04524847],
#        [0.8870086 , 0.8244654 , 0.8072694 , ..., 0.18479422, 0.17857024,
#         0.2284598 ]], dtype=float32)

# %%
features=['chroma_stft','chroma_cqt','chroma_cens','mfcc','spectral_centroid','spectral_bandwidth','spectral_rolloff','tonnetz','spectral_contrast']

# %%
for index, row in df.iterrows():
    audio_file = f"C:/Users/slayer/Desktop/Newfolder2/{row.title} {row.artist}.wav"
    y, sr = librosa.load(audio_file)
    for feature in features:
        feature_array = getattr(librosa.feature, feature)(y=y, sr=sr)
        for index2 in range(0,feature_array.shape[0]):
            df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
            df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
            df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
            df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
            df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
            df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
            df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# Out:
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:12: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
# C:\Users\slayer\AppData\Local\Temp\ipykernel_10120\4234669124.py:13: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])
# C:\Users\slayer\anaconda3\lib\site-packages\librosa\core\pitch.py:102: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
features=['rms','zero_crossing_rate']

# %%
for index, row in df.iterrows():
    audio_file = f"C:/Users/slayer/Desktop/Newfolder2/{row.title} {row.artist}.wav"
    y, sr = librosa.load(audio_file)
    for feature in features:
        feature_array = getattr(librosa.feature, feature)(y=y)
        for index2 in range(0,feature_array.shape[0]):
            df.loc[index,f'{feature}{index2}min']=np.min(feature_array[index2])
            df.loc[index,f'{feature}{index2}mean']=np.mean(feature_array[index2])
            df.loc[index,f'{feature}{index2}median']=np.median(feature_array[index2])
            df.loc[index,f'{feature}{index2}max']=np.max(feature_array[index2])
            df.loc[index,f'{feature}{index2}std']=np.std(feature_array[index2])
            df.loc[index,f'{feature}{index2}skew']=skew(feature_array[index2])
            df.loc[index,f'{feature}{index2}kurtosis']=kurtosis(feature_array[index2])

# %%
df
# Out:
#                           title                         artist  Popularity  \
# 0                    Heat Waves                  Glass Animals           1
# 1                     As It Was                   Harry Styles           1
# 2                          Stay  The Kid LAROI & Justin Bieber           1
# 3                    Easy On Me                          Adele           1
# 4                       Shivers                     Ed Sheeran           1
# ..                          ...                            ...         ...
# 886   Havana (feat. Young Thug)                 Camila Cabello           0
# 887     My Oh My (feat. DaBaby)                 Camila Cabello           0
# 888                Don't Go Yet                 Camila Cabello           0
# 889  Bam Bam (feat. Ed Sheeran)                 Camila Cabello           0
# 890                    Paradise                          Bazzi           0
#
#      chroma_stft0min  chroma_stft0mean  chroma_stft0median  chroma_stft0max  \
# 0           0.059570          0.545835            0.533538              1.0
# 1           0.015278          0.275441            0.220618              1.0
# 2           0.003058          0.404499            0.303639              1.0
# 3           0.022964          0.520444            0.448769              1.0
# 4           0.011911          0.306385            0.248289              1.0
# ..               ...               ...                 ...              ...
# 886         0.003528          0.356988            0.225380              1.0
# 887         0.006371          0.309186            0.138678              1.0
# 888         0.005112          0.435054            0.343724              1.0
# 889         0.009845          0.420395            0.307765              1.0
# 890         0.013117          0.423746            0.356778              1.0
#
#      chroma_stft0std  chroma_stft0skew  chroma_stft0kurtosis  ...   rms0std  \
# 0           0.256356          0.082964             -1.077184  ...  0.118361
# 1           0.227229          1.421235              1.736412  ...  0.069799
# 2           0.318527          0.687863             -0.836097  ...  0.118551
# 3           0.363116          0.184452             -1.552747  ...  0.074700
# 4           0.234466          1.032283              0.458042  ...  0.094986
# ..               ...               ...                   ...  ...       ...
# 886         0.329483          0.972939             -0.484435  ...  0.090464
# 887         0.333071          1.067800             -0.268092  ...  0.059601
# 888         0.313984          0.552945             -0.982608  ...  0.077071
# 889         0.346236          0.609563             -1.079443  ...  0.057873
# 890         0.274292          0.651191             -0.645266  ...  0.089567
#
#      rms0skew  rms0kurtosis  zero_crossing_rate0min  zero_crossing_rate0mean  \
# 0    0.461793     -0.740521                0.006348                 0.040369
# 1   -0.636223      0.176648                0.020508                 0.058005
# 2    0.159358     -0.991634                0.005859                 0.091604
# 3   -0.013273     -0.652805                0.005371                 0.076953
# 4    0.539557      0.497728                0.008301                 0.175090
# ..        ...           ...                     ...                      ...
# 886 -0.716734     -0.563802                0.013672                 0.077117
# 887  0.083784     -0.591777                0.009277                 0.090098
# 888 -0.646991      0.722369                0.008301                 0.065984
# 889 -0.155593     -0.679073                0.020508                 0.105433
# 890  0.779537      0.162482                0.006348                 0.062923
#
#      zero_crossing_rate0median  zero_crossing_rate0max  \
# 0                     0.030762                0.199219
# 1                     0.049805                0.283203
# 2                     0.084473                0.315918
# 3                     0.062988                0.316895
# 4                     0.170410                0.628906
# ..                         ...                     ...
# 886                   0.054688                0.504883
# 887                   0.071777                0.328125
# 888                   0.064453                0.224609
# 889                   0.100098                0.300293
# 890                   0.052246                0.166016
#
#      zero_crossing_rate0std  zero_crossing_rate0skew  \
# 0                  0.030786                 1.554403
# 1                  0.034028                 3.082647
# 2                  0.052741                 1.006604
# 3                  0.049250                 1.615687
# 4                  0.092736                 1.249098
# ..                      ...                      ...
# 886                0.064174                 2.788147
# 887                0.051047                 1.758010
# 888                0.027325                 0.957931
# 889                0.041518                 1.716334
# 890                0.035670                 0.544225
#
#      zero_crossing_rate0kurtosis
# 0                       2.892792
# 1                      11.735584
# 2                       1.631012
# 3                       3.046706
# 4                       3.291072
# ..                           ...
# 886                    11.397231
# 887                     3.717508
# 888                     3.353160
# 889                     5.229385
# 890                    -0.876939
#
# [891 rows x 521 columns]

# %%
df.to_csv('FinalPhase1).csv',index=False)
